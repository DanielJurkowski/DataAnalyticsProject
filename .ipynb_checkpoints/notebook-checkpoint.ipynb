# %% [markdown]
# ## **Effects of alcohol on student performance**
# ### Data Analytics
# ### Automatic Control and Robotics, Cyber-physical Systems
# #### **Daniel Jurkowski (407200) & Adam Pękala (405380)**

# %% [markdown]
# #### Modules import

# %%
from cmdstanpy import CmdStanModel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import arviz as az
import seaborn as sns
import cmdstanpy

# %% [markdown]
# #### CmdStanPy installation

# %%
cmdstanpy.install_cmdstan()
# Out:
# CmdStan install directory: /home/daniel/.cmdstan
# CmdStan version 2.35.0 already installed
# Test model compilation
# True

# %% [markdown]
# ## 1. Problem formulation - statement, point of creating model and data origin.
#
# Alcohol use among students is a topic of interest due to its potential impact on educational outcomes. This project aims to explore the relationship between alcohol consumption and student grades (GPA - Grade Point Average), with a focus on predicting academic performance based on alcohol consumption patterns. We will create statistical models to analyze how alcohol use influences students’ achievements. Understanding these effects can inform educational institutions and policymakers in promoting healthier behaviors among students.
#
# The data used for this project comes from an anonymous survey comprising sixteen questions meticulously crafted and distributed across diverse student chat forums at Stellenbosch University in South Africa in 2023. The author, from the Department of Statistics and Actuarial Science, focused on collecting information about gender, grade point average, faculty studied at, hours spent studying, personal life situations, and socializing habits related to alcohol use.
#
#
# |                                          **Column name**                                          |                                                       **Description**                                                      |
# |:-------------------------------------------------------------------------------------------------:|:--------------------------------------------------------------------------------------------------------------------------:|
# | Your Sex?                                                                                         | The sex of the student                                                                                                     |
# | Your Matric (grade 12) Average/ GPA (in %)                                                        | The students academic average (GPA) achieved in Matric (Year 12)                                                           |
# | What year were you in last year (2023) ?                                                          | Current academic year at Stellenbosch University                                                                           |
# | What faculty does your degree fall under?                                                         | The academic department to which the student's degree program belongs                                                      |
# | Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                | The academic average of the student for their prior year of studies at Stellenbosch University                             |
# | Your Accommodation Status Last Year (2023)                                                        | The student's accommodation status, which may include either private lodging or non-private/university-provided housing    |
# | Monthly Allowance in 2023                                                                         | The budgetary range within the student's monthly allowance are situated                                                    |
# | Were you on scholarship/bursary in 2023?                                                          | Wheter the student is enrolled in scholarship or funding program                                                           |
# | Additional amount of studying (in hrs) per week                                                   | The number of additional hours student work beyond their standard class schedule                                           |
# | How often do you go out partying/socialising during the week?                                     | The frequency with which a student engages in social activities, whether during weekdays or weekends                       |
# | On a night out, how many alcoholic drinks do you consume?                                         | The quantity of alcoholic beverages consumed by the student during socialising                                             |
# | How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?) | The count of classes missed by the student during the week due to alcohol-related reasons, such as experiencing a hangover |
# | How many modules have you failed thus far into your studies?                                      | The total count of modules failed by the student thus far in their academic journey at Stellenbosch University             |
# | Are you currently in a romantic relationship?                                                     | Whether the student is currently involved in a romantic relationship or not                                                |
# | Do your parents approve alcohol consumption?                                                      | Whether the student has obtained parental approval for alcohol consumption or not                                          |
# | How strong is your relationship with your parent(s)?                                               | The level of strength or closeness in the student's relationship with their parents

# %% [markdown]
# ### 1.1 Data exploring
#
# In order to gain a deeper understanding of this dataset, we display basic information about it. Additionally, we present some charts to illustrate the relationships between the different columns. This may prove useful for further reasoning and development of the project.

# %%
raw_data = pd.read_csv("data/survey.csv")
raw_data.head()
# Out:
#                    Timestamp Your Sex?  \
# 0  2024/03/07 5:12:01 pm EET    Female
# 1  2024/03/07 5:12:08 pm EET      Male
# 2  2024/03/07 5:12:25 pm EET      Male
# 3  2024/03/07 5:12:28 pm EET      Male
# 4  2024/03/07 5:13:00 pm EET    Female
#
#    Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                        76.0
# 1                                        89.0
# 2                                        76.0
# 3                                        89.0
# 4                                        74.0
#
#   What year were you in last year (2023) ?  \
# 0                                 2nd Year
# 1                                 2nd Year
# 2                                 1st Year
# 3                                 2nd Year
# 4                                 2nd Year
#
#   What faculty does your degree fall under?  \
# 0                    Arts & Social Sciences
# 1            Economic & Management Sciences
# 2                              AgriSciences
# 3                               Engineering
# 4                    Arts & Social Sciences
#
#    Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)  \
# 0                                               72.0
# 1                                               75.0
# 2                                               55.0
# 3                                               84.0
# 4                                               52.0
#
#         Your Accommodation Status Last Year (2023) Monthly Allowance in 2023  \
# 0  Private accommodation/ stay with family/friends            R 4001- R 5000
# 1  Private accommodation/ stay with family/friends           R 7001 - R 8000
# 2  Private accommodation/ stay with family/friends            R 4001- R 5000
# 3  Private accommodation/ stay with family/friends           R 6001 - R 7000
# 4  Private accommodation/ stay with family/friends            R 4001- R 5000
#
#   Were you on scholarship/bursary in 2023?  \
# 0                                       No
# 1                      Yes (NSFAS, etc...)
# 2                                       No
# 3                                       No
# 4                                       No
#
#   Additional amount of studying (in hrs) per week  \
# 0                                              8+
# 1                                              8+
# 2                                             3-5
# 3                                             3-5
# 4                                             3-5
#
#   How often do you go out partying/socialising during the week?   \
# 0                                      Only weekends
# 1                                      Only weekends
# 2                                                  2
# 3                                                  3
# 4                                      Only weekends
#
#   On a night out, how many alcoholic drinks do you consume?  \
# 0                                                 8+
# 1                                                3-5
# 2                                                 8+
# 3                                                 8+
# 4                                                5-8
#
#   How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  \
# 0                                                  3
# 1                                                 4+
# 2                                                  3
# 3                                                  2
# 4                                                  1
#
#   How many modules have you failed thus far into your studies?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  3
#
#   Are you currently in a romantic relationship?  \
# 0                                           Yes
# 1                                            No
# 2                                            No
# 3                                           Yes
# 4                                            No
#
#   Do your parents approve alcohol consumption?  \
# 0                                          Yes
# 1                                          Yes
# 2                                          Yes
# 3                                          Yes
# 4                                          Yes
#
#   How strong is your relationship with your parent/s?
# 0                                         Very close
# 1                                         Very close
# 2                                         Very close
# 3                                         Very close
# 4                                               Fair

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Timestamp                                                                                          406 non-null    object
#  1   Your Sex?                                                                                          404 non-null    object
#  2   Your Matric (grade 12) Average/ GPA (in %)                                                         399 non-null    float64
#  3   What year were you in last year (2023) ?                                                           333 non-null    object
#  4   What faculty does your degree fall under?                                                          399 non-null    object
#  5   Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                 320 non-null    float64
#  6   Your Accommodation Status Last Year (2023)                                                         383 non-null    object
#  7   Monthly Allowance in 2023                                                                          375 non-null    object
#  8   Were you on scholarship/bursary in 2023?                                                           398 non-null    object
#  9   Additional amount of studying (in hrs) per week                                                    403 non-null    object
#  10  How often do you go out partying/socialising during the week?                                      404 non-null    object
#  11  On a night out, how many alcoholic drinks do you consume?                                          404 non-null    object
#  12  How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  403 non-null    object
#  13  How many modules have you failed thus far into your studies?                                       403 non-null    object
#  14  Are you currently in a romantic relationship?                                                      403 non-null    object
#  15  Do your parents approve alcohol consumption?                                                       402 non-null    object
#  16  How strong is your relationship with your parent/s?                                                403 non-null    object
# dtypes: float64(2), object(15)
# memory usage: 54.1+ KB

# %%
selected_columns = [1, 3, 4, 6, 7, 8, 9, 14, 15, 16]
initials = ['parents approval', 'parents relationship with their children',
           'relationship status', 'studying hours', 'scholarship status', 'allowance',
           'accommodation', 'year of study', 'faculty', 'gender']


for i, j in enumerate(selected_columns):    
    cross = pd.crosstab(raw_data[raw_data.columns[j]], raw_data[raw_data.columns[10]])
    sns.heatmap(cross, annot=True)
    plt.title(f'Influence of {initials[i]} on socializing')
    plt.show()

# %%
sns.heatmap(pd.crosstab(raw_data[raw_data.columns[10]], raw_data[raw_data.columns[11]]), annot=True)
plt.title('Correlation between socializing and number of drinks per occasion')
plt.show()

# %%
sns.heatmap(pd.crosstab(raw_data[raw_data.columns[11]], raw_data[raw_data.columns[7]]), annot=True)
plt.title('Number of drinks based on allowance')
plt.show()

# %%
sns.heatmap(pd.crosstab(raw_data[raw_data.columns[10]], raw_data[raw_data.columns[12]]), annot=True)
plt.title('Skipped classes due to socializing')
plt.show()

# %%
sns.heatmap(pd.crosstab(raw_data[raw_data.columns[10]], raw_data[raw_data.columns[13]]), annot=True)
plt.title('Socializing influence on a number of modules failed')
plt.show()

# %%
sns.kdeplot(raw_data, x=raw_data.columns[2], hue=raw_data.columns[9])
plt.title('Influence of additional hours of studying on GPA')
plt.show()

# %%
sns.kdeplot(raw_data, x=raw_data.columns[2], hue=raw_data.columns[10])
plt.title('Influence of socializing on GPA')
plt.show()

# %%
sns.kdeplot(raw_data, x=raw_data.columns[2], hue=raw_data.columns[11])
plt.title('Influence of number of drinks during socializing on GPA')
plt.show()

# %% [markdown]
# ### 1.2 DAG diagram

# %% [markdown]
# Only few of the features are choosen to be used in our models - in our opinion the most influential ones for the student performance.
# A DAG is created to illustrate the relationships between that features and the target variable (GPA).
#
# <p align="center">
#     <img src="images/DAG_.png" width=800px/ >
# </p>
#
# **Legend:**
# * Colours meaning:
#     * Green - ordered categorical variable,
#     * Red  - binary variable,
#     * Orange - target (real variable).
#
# * Lines meaning:
#     * Continuous line - association between block,
#     * Dashed line - weak association between data.
#
# * Framed features are used in the models.

# %% [markdown]
# ### 1.2 Confoundings

# %% [markdown]
# * Fork
#
#     * "Drinks consummed at the party" feature is common cause for "Studying hours" and "Missed classes".
#
#     * "Hangouts" influences both "Drinks consummed at the party" and "Studying hours".
#
# * Collider
#
#     * "Studying hours" is infulenced by "Hangouts" and "Drinks consummed at the party".
#
#     * "Drinks consummed at the party" is influenced by "Hangouts" and "Parents alcohol approvement".
#
#     * "GPA" is influenced by "Studying hours", "Missed classes", "Drinks consummed at the party", "Studying hours", "Hangouts".
#
# * Pipe
#
#     * "Parents alcohol approvement" can influence "Drinks consummed at the party" and is transmited to "GPA".

# %% [markdown]
# ## 2. Data preprocessing describe and reasoning
# Despite using only few of the features, the whole data set is preprocessed for the sake of completeness. The following steps are taken:
#
# * timestamp column will be dropped as it doesn't give any useful information for our purposes,
# * to work with the gathered data, we’ll simplify column names for easier reference. This practice improves readability and reduces typing effort,
# * rows containing NaN or missing values will be dropped. This ensures that our dataset remains clean and accurate,
# * values described by two options (e.g., “yes” and “no”), will be converted  to binary format ("0" or "1"). This simplifies the representation,
# * values describing incremental features (e.g., “very close,” “close,” “fair,” “distant”) will be mapped to numerical values ("3", "2", "1", "0"). Same thing will be applied to values with range format,
# * the value “Only weekends” describing social activities will be changed to “1” for simplification, even though it differs from the actual value “1” (which represents drinking on weekdays, because it can have less influence on academic performance),
# * faculties will be ranked subjectively from easiest to hardest for passing.

# %%
data = raw_data.copy()

# Rename columns and drop timestamp column
columns_names = {
    data.columns[1]: "Gender",
    data.columns[2]: "Current GPA",
    data.columns[3]: "Year",
    data.columns[4]: "Faculty",
    data.columns[5]: "Prior GPA",
    data.columns[6]: "Accommodation",
    data.columns[7]: "Allowance",
    data.columns[8]: "Scholarship",
    data.columns[9]: "Studying hours",
    data.columns[10]: "Hangouts",
    data.columns[11]: "Drinks",
    data.columns[12]: "Missed classes",
    data.columns[13]: "Failed modules",
    data.columns[14]: "Relationship",
    data.columns[15]: "Parents approvement",
    data.columns[16]: "Relationship with parents",}

data.rename(columns = columns_names, inplace=True)
data = data.drop('Timestamp', axis=1)
data.head()
# Out:
#    Gender  Current GPA      Year                         Faculty  Prior GPA  \
# 0  Female         76.0  2nd Year          Arts & Social Sciences       72.0
# 1    Male         89.0  2nd Year  Economic & Management Sciences       75.0
# 2    Male         76.0  1st Year                    AgriSciences       55.0
# 3    Male         89.0  2nd Year                     Engineering       84.0
# 4  Female         74.0  2nd Year          Arts & Social Sciences       52.0
#
#                                      Accommodation        Allowance  \
# 0  Private accommodation/ stay with family/friends   R 4001- R 5000
# 1  Private accommodation/ stay with family/friends  R 7001 - R 8000
# 2  Private accommodation/ stay with family/friends   R 4001- R 5000
# 3  Private accommodation/ stay with family/friends  R 6001 - R 7000
# 4  Private accommodation/ stay with family/friends   R 4001- R 5000
#
#            Scholarship Studying hours       Hangouts Drinks Missed classes  \
# 0                   No             8+  Only weekends     8+              3
# 1  Yes (NSFAS, etc...)             8+  Only weekends    3-5             4+
# 2                   No            3-5              2     8+              3
# 3                   No            3-5              3     8+              2
# 4                   No            3-5  Only weekends    5-8              1
#
#   Failed modules Relationship Parents approvement Relationship with parents
# 0              0          Yes                 Yes                Very close
# 1              0           No                 Yes                Very close
# 2              0           No                 Yes                Very close
# 3              0          Yes                 Yes                Very close
# 4              3           No                 Yes                      Fair

# %%
# Check data for unique values, and check if NaN or missing values are present
for column in data:
    print(data[column].unique())
# Out:
# ['Female' 'Male' nan]
# [76.   89.   74.   83.   80.   85.   75.   79.   72.   78.   87.   86.
#  69.   73.   84.   99.   82.6  65.   81.   88.   70.   98.   90.   98.33
#    nan 82.   77.   68.   66.   92.   91.86 71.   63.   67.   60.   94.
#  95.   34.   86.4  95.5  55.   91.21 96.   64.  ]
# ['2nd Year' '1st Year' nan '3rd Year' '4th Year' 'Postgraduate']
# ['Arts & Social Sciences' 'Economic & Management Sciences' 'AgriSciences'
#  'Engineering' 'Science' 'Medicine and Health Services' 'Law' 'Education'
#  nan]
# [72.   75.   55.   84.   52.     nan 54.   64.   76.   65.   62.   69.
#  60.   74.   70.   63.   73.   57.   90.   78.   61.   89.   80.   66.
#  58.   95.22 71.   53.   50.   88.   79.   56.   51.   68.   77.   65.89
#  73.5  59.   67.   92.   87.6  83.   30.   81.   69.7  85.  ]
# ['Private accommodation/ stay with family/friends' nan
#  'Non-private accommodation ie. Res']
# ['R 4001- R 5000' 'R 7001 - R 8000' 'R 6001 - R 7000' 'R 5001 - R 6000'
#  nan 'R 8000+']
# ['No' 'Yes (NSFAS, etc...)' nan]
# ['8+' '3-5' '5-8' '1-3' '0' nan]
# ['Only weekends' '2' '3' '4+' '1' '0' nan]
# ['8+' '3-5' '5-8' '1-3' '0' nan]
# ['3' '4+' '2' '1' '0' nan]
# ['0' '3' '1' nan '4+' '2']
# ['Yes' 'No' nan]
# ['Yes' 'No' nan]
# ['Very close' 'Fair' 'Close' 'Distant' nan]

# %%
# Drop rows with NaN (missing) values, use mapping to change values to more readable format
data.dropna(axis=0, how='any', inplace=True)


# Create mapping values for each column
gender_map = {
    'Female': 1,
    'Male': 0
}

year_map = {
    '1st Year': 0,
    '2nd Year': 1,
    '3rd Year': 2,
    '4th Year': 3,
    'Postgraduate': 4
}

faculty_map = {
    'AgriSciences': 0,
    'Arts & Social Sciences': 1,
    'Education': 2,
    'Economic & Management Sciences': 3,
    'Medicine and Health Services': 4,
    'Science': 5,
    'Engineering': 6,
    'Law': 7
}

accommodation_map = {
    'Private accommodation/ stay with family/friends': 1,
    'Non-private accommodation ie. Res': 0
}

allowance_map = {
    'R 4001- R 5000': 0,
    'R 5001 - R 6000': 1,
    'R 6001 - R 7000': 2,
    'R 7001 - R 8000': 3,
    'R 8000+': 4,
}

scholarship_map = {
    'Yes (NSFAS, etc...)' : 1,
    'No' : 0
}

study_hours_map = {
    '0': 0,
    '1-3': 1,
    '3-5': 2,
    '5-8': 3,
    '8+': 4
}

hangouts_map = {
    '0': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4+': 4,
    'Only weekends' : 1
}

drinks_map = {
    '0': 0,
    '1-3': 1,
    '3-5': 2,
    '5-8': 3,
    '8+': 4
}

missed_classes_map = {
    '0': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4+': 4
}

failed_modules_map = {
    '0': 0,
    '1': 1,
    '2': 2,
    '3': 3,
    '4+': 4
}

relationship_map = {
    'Yes' : 1,
    'No' : 0
}

parents_approvement_map = {
    'Yes' : 1,
    'No' : 0
}

parents_relationship_map = {
    'Distant' : 0,
    'Fair' : 1,
    'Close' : 2,
    'Very close' : 3
}

maps = {
    'Gender': gender_map,
    'Year': year_map,
    'Faculty': faculty_map,
    'Accommodation': accommodation_map,
    'Allowance': allowance_map,
    'Scholarship': scholarship_map,
    'Studying hours': study_hours_map,
    'Hangouts': hangouts_map,
    'Drinks': drinks_map,
    'Missed classes': missed_classes_map,
    'Failed modules': failed_modules_map,
    'Relationship': relationship_map,
    'Parents approvement': parents_approvement_map,
    'Relationship with parents': parents_relationship_map
}

for column in data:
    if column not in ['Current GPA', 'Prior GPA']:
        data[column] = data[column].map(lambda x: maps[column].get(x, x))
        
data.head()
# Out:
#    Gender  Current GPA  Year  Faculty  Prior GPA  Accommodation  Allowance  \
# 0       1         76.0     1        1       72.0              1          0
# 1       0         89.0     1        3       75.0              1          3
# 2       0         76.0     0        0       55.0              1          0
# 3       0         89.0     1        6       84.0              1          2
# 4       1         74.0     1        1       52.0              1          0
#
#    Scholarship  Studying hours  Hangouts  Drinks  Missed classes  \
# 0            0               4         1       4               3
# 1            1               4         1       2               4
# 2            0               2         2       4               3
# 3            0               2         3       4               2
# 4            0               2         1       3               1
#
#    Failed modules  Relationship  Parents approvement  \
# 0               0             1                    1
# 1               0             0                    1
# 2               0             0                    1
# 3               0             1                    1
# 4               3             0                    1
#
#    Relationship with parents
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 295 entries, 0 to 402
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Gender                     295 non-null    int64
#  1   Current GPA                295 non-null    float64
#  2   Year                       295 non-null    int64
#  3   Faculty                    295 non-null    int64
#  4   Prior GPA                  295 non-null    float64
#  5   Accommodation              295 non-null    int64
#  6   Allowance                  295 non-null    int64
#  7   Scholarship                295 non-null    int64
#  8   Studying hours             295 non-null    int64
#  9   Hangouts                   295 non-null    int64
#  10  Drinks                     295 non-null    int64
#  11  Missed classes             295 non-null    int64
#  12  Failed modules             295 non-null    int64
#  13  Relationship               295 non-null    int64
#  14  Parents approvement        295 non-null    int64
#  15  Relationship with parents  295 non-null    int64
# dtypes: float64(2), int64(14)
# memory usage: 39.2 KB

# %%
for column in data:
    print(data[column].unique())
# Out:
# [1 0]
# [76.   89.   74.   80.   85.   79.   72.   87.   69.   83.   78.   84.
#  86.   73.   99.   82.6  65.   81.   88.   75.   98.   90.   98.33 70.
#  82.   77.   68.   92.   71.   63.   67.   95.   86.4  60.   95.5  94.
#  66.   64.  ]
# [1 0 2 3 4]
# [1 3 0 6 5 7 4 2]
# [72.   75.   55.   84.   52.   54.   64.   76.   65.   62.   69.   60.
#  74.   70.   63.   73.   57.   90.   78.   61.   89.   80.   66.   58.
#  95.22 71.   53.   88.   79.   56.   51.   68.   50.   77.   73.5  59.
#  67.   92.   87.6  83.   30.   81.   69.7  85.  ]
# [1 0]
# [0 3 2 1 4]
# [0 1]
# [4 2 1 3 0]
# [1 2 3 4 0]
# [4 2 3 1 0]
# [3 4 2 1 0]
# [0 3 4 1 2]
# [1 0]
# [1 0]
# [3 1 2 0]

# %%
data.to_csv('data/survey_cleaned.csv', index=False, sep=',')

# %%
data = data.reset_index()

# %% [markdown]
# ## 3. Model - differences, justification
# For the purpose of this project, two statistical models are developed, each utilizing a different probability distribution for predicted student's performance.
#
# First model take in information about studying hours, average alcohol consumption per hangout and hangouts during the week, these components are transformed and will result in a **normal distribution**.
#
# The second model uses the same inputs however, with the components being transformed and used in the **beta distribution**.
#
#
# - The normal distribution is selected for the first model, because it is particularly effective in modeling phenomena where outcomes tend to cluster around a central mean. This characteristic makes this distribution suitable for predicting GPA when we assume that the GPA scores are influenced by a variety of factors that have a cumulative effect, leading to a clustering of scores around a mean value.
#
# - On the other hand, the Beta distribution is chosen for the second model because of its flexibility and the nature of its defining parameters, α (alpha) and β (beta). These parameters allow the beta distribution to assume a wide range of shapes, including uniform, U-shaped, or J-shaped distributions, making it exceptionally versatile for modeling data. Given that the beta distribution is confined to the interval [0, 1], it is particularly useful at modeling variables with limited domain. This makes it a good choice for modeling GPA as a proportion of the total possible points a student can achieve.

# %% [markdown]
# ### 3.1 First model - specification, description
# This model is a Bayesian linear regression model implemented in Stan, aiming to predict a continuous outcome (GPA) based on three predictors: hours of study, amount of socializing activities (hangouts), and average amount of drinks consumed during them. The model uses a linear combination of these predictors, each weighted by a coefficient, to estimate the GPA. Priors for the coefficients and the shift term follow normal distributions. The model calculates the expected GPA for each observation and assesses the likelihood of the observed GPAs given these expectations.
#
# **Inputs**:
# * N - number of observations,
# * gpa[N] - continuous outcome representing the GPA of each student, constrained between 0 and 100,
# * hours[N] - fisrt predictor, representing the number of hours a student works, constrained between 0 and 4.
# * hangouts[N] - second predictor, representing the amount of socializing activities, constrained between 0 and 4,
# * drinks[N] - third predictor, representing the amount of consumed drinks at one party, constrained between 0 and 4.
#
#
# **Parameters**:
# * $\theta_{1}$ - shift coeficient of the linear model,
# * $\theta_{2}$  - coefficient for the hours predictor,
# * $\theta_{3}$  - coefficient for the hangouts predictor,
# * $\theta_{4}$  - coefficient for the drinks predictor,
# * $\sigma$ - standard deviation of the GPA predictions constrained to be positive.
#
# **Transformed parameters**:
# * $\mu$[N] = $\theta_{1}$ + $\theta_{2}$ * hours[N] + $\theta_{3}$ * hangouts[N] + $\theta_{4}$ * drinks[N]
#
# **Model**:
#
# $$\theta_{1} \sim Normal(70, 3)$$
# $$\theta_{2} \sim Normal(1.5, 0.2)$$
# $$\theta_{3} \sim Normal(-0.5, 0.3)$$
# $$\theta_{4} \sim Normal(-0.75, 0.3)$$
# $$\sigma \sim Normal(5, 0.5)$$
# $$gpa[i] \sim Normal(\mu[i], \sigma)$$
#
#
# **Quantities generation**:
#
# * predicted_gpa = fmin(normal_rng(mu[i],sigma), 100)

# %% [markdown]
# ### 3.2 Second model  - specification, description
# This model is a Bayesian hierarchical model designed to predict a scaled GPA (ranging from 0 to 1) based on three predictors: hours of study, amount of socializing activities (hangouts), and average amount of drinks consumed during them. Unlike traditional linear regression models, this model uses a beta distribution for the outcome variable, making it suitable for modeling outcomes that fall within a bounded interval (0, 1).
#
# **Inputs**:
# * N: number of observations,
# * scaled_gpa[N]: conttinous outcome variable, representing scaled GPA, constrained between 0 and 1.
# * hours[N] - fisrt predictor, representing the number of hours a student works, constrained between 0 and 4.
# * hangouts[N] - second predictor, representing the amount of socializing activities, constrained between 0 and 4,
# * drinks[N] - third predictor, representing the amount of consumed drinks at one party, constrained between 0 and 4.
#
# **Parameters**:
# * $\theta_{1}$ - factor for the shape parameter alpha.
# * $\theta_{2}$ - coefficient for the hours predictor,
# * $\theta_{3}$ - factor for the shape parameter beta,
# * $\theta_{4}$ - coefficient for the hangouts predictor,
# * $\theta_{5}$ - coefficient for the drinks predictor.
#
# **Transformed Parameters**:
# * alpha[N]: Derived parameter for the alpha shape parameter for each observation, calculated as sum of $\theta_{1}$ and $\theta_{2}$ coefficient with the hours predictor.
# * beta[N]: Derived parameter for the beta shape for each observation, calculated using sum of $\theta_{3}$ and coefficients $\theta_{4}$, and $\theta_{5}$ for hangouts and drinks predictors.
#
# **Model**:
# $$\theta_{1} \sim LogNormal(3.63, 0.02)$$
# $$\theta_{2} \sim LogNormal(0.4, 0.1)$$
# $$\theta_{3}  \sim LogNormal(2.3, 0.1)$$
# $$\theta_{4} \sim LogNormal(0.01, 0.1)$$
# $$\theta_{5} \sim LogNormal(0.01, 0.1)$$
# $$scaled\_gpa[i] \sim Beta(alpha[i], beta[i])$$
#
#
# **Generated Quantities**:
# * predicted_scaled_gpa[i] = beta_rng(alpha[i], beta[i]);
#
# Model is particularly suited for outcomes that are proportions within a fixed interval, leveraging the flexibility of the beta distribution to accommodate various shapes of the data distribution. The hierarchical structure allows for individual-level variation through the predictors, capturing complex relationships between the predictors and the outcome.

# %% [markdown]
# ## 4. Priors
# The choice of prior distributions is based on common statistical assumptions about the nature of the given data and the factors influencing the parameter of interest.
#
# In order to compare the results obtained from the prior, the histogram of the current GPA values is presented. Additionally, the average value was calculated along with the standard deviation.

# %%
sns.histplot(data['Current GPA'], bins=len(data['Current GPA'].unique()))
plt.xlabel('Current GPA [%]')
plt.title('Histogram of current GPA')
plt.grid()
plt.show()

print("Mean value of Current GPA: ", data['Current GPA'].mean())
print("Std. value of Current GPA: ", data['Current GPA'].std())
# Out:
# Mean value of Current GPA:  78.20959322033899
# Std. value of Current GPA:  6.5774609349637565

# %% [markdown]
# ### 4.1 Prior for the first model

# %% [markdown]
# **Theta_1 shift coeficient**:
# The main factor influencing the prior predicted_gpa value is the theta_1 shift defined by a normal distribution in the region of 75%. The coefficient was chosen based on general knowledge of the students' average performance.
#
# **Theta_2 Studying Hours predictor coeficient**:
# The normal distribution is chosen for scaling continuous variables like studying hours because it’s a common assumption that such variables tend to follow a bell-shaped distribution in a population. The values from the dataset were multiplied by a distribution centred on the coefficient theta_2, which is, so to speak, a ‘weigh’ for the input value of ‘hours’ and thus determines the impact of the hours spent on the overall predicted GPA.
#
# **Theta_3 Hangouts predictor coeficient**:
# Analogous to the previous parameter, for the "hangouts" input, a negative weight was chosen because, as is generally known, going out and spending time on meetings and entertainment instead of studying has a negative impact on the overall outcome of the study.
#
# **Theta_4 Drinks predictor coeficient**:
# Prior for "drinks" input is chosen in the same way as "hangouts" but was defined as greater because alcohol has a bigger impact on negative outcomes than simply spending time having fun.
#
# **Predicted GPA**:
# The predicted GPA is generated using a normal distribution where the mean is a linear combination of studying hours, hangouts, drinks and theta_1 as shift coeficient of the linear model. This factor has the greatest influence on the predicted values, having been selected on the basis of general knowledge of the average student grade, which fluctuates around 70%. A sigma value is used to ensure that the generated GPAs are densely packed around the mean, reflecting the expectation that most GPAs will be close to the average with some variation.
#
# **Sigma**:
# The standard deviation parameter sigma, also defined using a normal distribution, based on knowledge of the variability of the mean distribution among students
#
# **Generated quantities:**
#
# * real theta_1 = normal_rng(75, 3);
# * real theta_2 = normal_rng(1.5, 0.2);
# * real theta_3 = normal_rng(-0.5, 0.3);
# * real theta_4 = normal_rng(-0.75, 0.3);
# * real sigma = normal_rng(5, 0.5);
#
# **Formula:**
#
# predicted_gpa[i] = normal_rng(theta_1 + theta_2 * hours[i] + theta_3 * hangouts[i] + theta_4 * drinks[i], sigma);

# %% [markdown]
# #### 4.1.1 Generating samples
# The number of iterations was chosen based on the number of records in the data.

# %%
hours_array = np.linspace(data['Studying hours'].min(), data['Studying hours'].max(), 10)
hangouts_array = np.linspace(data['Hangouts'].min(), data['Hangouts'].max(), 10)
drinks_array = np.linspace(data['Drinks'].min(), data['Drinks'].max(), 10)

# %%
prior_model_1 = CmdStanModel(stan_file='src/prior_model_1.stan')

R = 295
data_simulated = {'N': 10,
                  'hours': hours_array,
                  'hangouts': hangouts_array,
                  'drinks': drinks_array
                  }  
samples_model_1 = prior_model_1.sample(data=data_simulated,
                                       iter_sampling=R,
                                       iter_warmup=1,
                                       chains=1,
                                       fixed_param=True,
                                       seed=2024,
                                       refresh=R)
# Out:
# 20:52:25 - cmdstanpy - INFO - compiling stan file /home/daniel/Documents/studies/data_analytics/project/src/prior_model_1.stan to exe file /home/daniel/Documents/studies/data_analytics/project/src/prior_model_1
# 20:52:37 - cmdstanpy - INFO - compiled model executable: /home/daniel/Documents/studies/data_analytics/project/src/prior_model_1
# 20:52:37 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 20:52:37 - cmdstanpy - INFO - CmdStan done processing.

# %%
df_1 = samples_model_1.draws_pd()
df_1.head()
# Out:
#    chain__  iter__  draw__  lp__  accept_stat__  predicted_gpa[1]  \
# 0      1.0     1.0     1.0   0.0            0.0           75.3889
# 1      1.0     2.0     2.0   0.0            0.0           68.4062
# 2      1.0     3.0     3.0   0.0            0.0           67.2216
# 3      1.0     4.0     4.0   0.0            0.0           57.9535
# 4      1.0     5.0     5.0   0.0            0.0           71.2736
#
#    predicted_gpa[2]  predicted_gpa[3]  predicted_gpa[4]  predicted_gpa[5]  \
# 0           81.9107           78.6546           83.5637           84.4029
# 1           81.9482           77.4942           71.8689           66.2801
# 2           93.3991           79.7620           70.1268           81.8465
# 3           80.0503           69.9027           71.9818           72.8547
# 4           67.7180           71.1164           77.0721           74.1389
#
#    predicted_gpa[6]  predicted_gpa[7]  predicted_gpa[8]  predicted_gpa[9]  \
# 0           77.4171           80.7093           80.0195           80.6495
# 1           74.4913           75.3833           84.9040           75.6598
# 2           71.5906           73.4551           73.4361           86.1832
# 3           72.0238           78.0597           75.3958           74.5123
# 4           76.4551           75.4993           75.2006           75.9310
#
#    predicted_gpa[10]  theta_1  theta_2   theta_3   theta_4    sigma
# 0            79.9888  78.2738  1.96616 -0.704317 -0.962350  4.47234
# 1            72.1642  73.1675  1.62852 -0.223507 -0.860637  5.13495
# 2            86.3217  76.6632  1.61263 -0.751453 -0.761853  4.33552
# 3            60.6533  71.8640  1.56050 -0.285845 -0.857026  5.32489
# 4            75.3106  72.7270  1.30805 -0.194604 -0.730232  4.21608

# %% [markdown]
# #### 4.1.2 Prior predictive checks for parameters and measurements

# %%
columns = [f'predicted_gpa[{i+1}]' for i in range(10)]

fig, axes = plt.subplots(5, 2, figsize=(10, 25))

for i, column in enumerate(columns):    
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.histplot(data['Current GPA'], ax=ax, bins=30, stat='density')
    sns.histplot(df_1[column], ax=ax, bins=30, stat='density')
    
    ax.set_title(f'Prior distribution {column}')
    ax.set_xlabel('Predicted GPA [%]')
    if i == 0:
        ax.legend(['Observed GPA', 'Predicted GPA'])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 10))
sns.histplot(df_1['theta_1'], ax=axes[0][0], bins=30, stat='density')
sns.histplot(df_1['theta_2'], ax=axes[0][1], bins=30, stat='density')
sns.histplot(df_1['theta_3'], ax=axes[1][0], bins=30, stat='density')
sns.histplot(df_1['theta_4'], ax=axes[1][1], bins=30, stat='density')
sns.histplot(df_1['sigma'], ax=axes[2][0], bins=30, stat='density')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.2 Prior for the second model

# %% [markdown]
# **Theta_1 and Theta_3 shift coeficients**:
# The main factors influencing the prior predicted_gpa value the theta_1 and theta_3 shift defined by a lognormal distribution. The values declared for lognormal distribution were chosen so that the form factors of the final beta distribution oscillate around 37 for the alpha coefficient and 10 for the beta coefficient.
#
# **Theta_2 Studying Hours predictor coeficient**:
# Same assumptions as in prior distribution for the first model, but a "weight" theta_2 was declared by lognormal distribution due to the fact that lognormal distribution is appropriate for variables that represent multiplicative effects. In many scenarios, underlying factors multiply rather than add. By using lognormal distributions, the model implicitly assumes that the effects of the predictors on the outcome (GPA) are multiplicative.
# In addition, this distribution provides positive values, which prevents the distribution shape factor from becoming negative.
#
# **Theta_4 Hangouts predictor coeficient**:
# Same assumptions as in prior distribution for the first model, also distributions changed to lognormal due to the same reasons as for "studying hours" coeficient theta_2.
#
# **Theta_5 Drinks predictor coeficient**:
# Same assumptions as in prior distribution for the first model, also distributions changed to lognormal due to the same reasons as for "studying hours" coeficient theta_2.
#
# **Predicted GPA**:
# For each observation, the model predicts the GPA using a beta distribution. The beta distribution is parameterized by two shape parameters, α (alpha) and β (beta), which in this model are calculated as linear combinations of the input variables (hours, hangouts, drinks) weighted by their respective coefficients (theta_2, theta_4, theta_5) and adjusted by theta_1 and theta_3.
# Parameter values were chosen so that the final distribution oscillates, as in the first model, close to 70%.
#
# The beta distribution naturally outputs values between 0 and 1, representing proportions. To convert these proportions to GPA scores on a 0-100 scale, the model multiplies the output of the beta distribution by 100.
#
# **Generated quantities:**
#
# * array[N] real<lower=0, upper=100> predicted_gpa;
#
# Adjust beta distribution for average 70-80% GPA
# * real theta_1 = lognormal_rng(3.63, 0.02);
# * real theta_3 = lognormal_rng(2.3, 0.1);
#
# Predictors coefficients
# * real theta_2 = lognormal_rng(0.4, 0.1);
# * real theta_4 = lognormal_rng(0.01, 0.1);
# * real theta_5 = lognormal_rng(0.01, 0.1);
#
# **Formula:**
#
# predicted_gpa[i] = 100 * beta_rng(theta_1 + theta_2 * hours[i], theta_3 + theta_4 * hangouts[i] + theta_5 * drinks[i]);

# %% [markdown]
# #### 4.2.1 Generating samples

# %%
prior_model_2 = CmdStanModel(stan_file='src/prior_model_2.stan')

data_simulated = {'N': 10,
                  'hours': hours_array,
                  'hangouts': hangouts_array,
                  'drinks': drinks_array
                  }  

samples_model_2 = prior_model_2.sample(data=data_simulated,
                                       iter_sampling=R,
                                       iter_warmup=1,
                                       chains=1,
                                       fixed_param=True,
                                       seed=20052024,
                                       refresh=R)
# Out:
# 20:52:41 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 20:52:41 - cmdstanpy - INFO - CmdStan done processing.

# %%
df_2 = samples_model_2.draws_pd()
df_2.head()
# Out:
#    chain__  iter__  draw__  lp__  accept_stat__  predicted_gpa[1]  \
# 0      1.0     1.0     1.0   0.0            0.0           68.2671
# 1      1.0     2.0     2.0   0.0            0.0           65.0414
# 2      1.0     3.0     3.0   0.0            0.0           70.9042
# 3      1.0     4.0     4.0   0.0            0.0           57.5034
# 4      1.0     5.0     5.0   0.0            0.0           80.2810
#
#    predicted_gpa[2]  predicted_gpa[3]  predicted_gpa[4]  predicted_gpa[5]  \
# 0           84.2709           80.4700           77.1909           64.8497
# 1           79.6014           67.7423           74.8960           88.2755
# 2           76.6358           67.3670           71.2758           79.0974
# 3           73.7627           73.8134           78.8622           67.0898
# 4           74.8735           82.7479           68.2968           63.9397
#
#    predicted_gpa[6]  predicted_gpa[7]  predicted_gpa[8]  predicted_gpa[9]  \
# 0           73.6265           62.6207           58.5990           75.6269
# 1           81.1673           75.9181           66.6863           62.7343
# 2           53.7367           53.9234           68.6162           74.7743
# 3           67.9267           53.6340           58.6507           69.7525
# 4           67.0707           75.9456           78.9044           72.1228
#
#    predicted_gpa[10]  theta_1   theta_3  theta_2   theta_4   theta_5
# 0            68.2699  37.7236  10.22460  1.41029  0.889726  1.040430
# 1            60.8247  38.3472   9.21924  1.51602  1.139950  0.978419
# 2            57.4649  38.2906  12.50500  1.62844  1.259540  0.982696
# 3            66.0009  35.6864  11.09460  1.82589  0.903061  1.085480
# 4            70.4297  39.6070   9.69720  1.49867  1.281020  1.033120

# %% [markdown]
# #### 4.2.2 Prior predictive checks for parameters and measurements

# %%
columns = [f'predicted_gpa[{i+1}]' for i in range(10)]

fig, axes = plt.subplots(5, 2, figsize=(10, 25))

for i, column in enumerate(columns):    
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.histplot(data['Current GPA'], ax=ax, bins=len(data['Current GPA'].unique()))
    sns.histplot(df_2[column], ax=ax, bins=30)
    
    ax.set_title(f'Prior distribution {column}')
    ax.set_xlabel('Predicted GPA [%]')
    if i == 0:
        ax.legend(['Observed GPA', 'Predicted GPA'])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 10))
sns.histplot(df_2['theta_1'], ax=axes[0][0], bins=30, stat='density')
sns.histplot(df_2['theta_2'], ax=axes[0][1], bins=30, stat='density')
sns.histplot(df_2['theta_3'], ax=axes[1][0], bins=30, stat='density')
sns.histplot(df_2['theta_4'], ax=axes[1][1], bins=30, stat='density')
sns.histplot(df_2['theta_5'], ax=axes[2][0], bins=30, stat='density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Posterior analysis for the first model

# %% [markdown]
# ### 5.1 Issues with the sampling for first model
#
# For the first posterior model, we encountered two important limitations during sampling. Namely, in extreme cases, the sigma predictor values, were negative, which caused errors and prevented subsequent model comparison. The second important change was that we had to introduce an upper limit for the generated GPA values, as values above 100% also appeared in extreme cases. The problem was solved using the fmin function rather than changing the predictor values, as this gave a better overall prediction.

# %%
np.random.seed(2024)

# %%
posterior_model_1 = CmdStanModel(stan_file='src/posterior_model_1.stan')

indexes = list(np.random.choice(range(295), 10, replace=False))
data_fit = {'N': 10, 
            'hours': (data['Studying hours'][indexes]),
            'hangouts': (data['Hangouts'][indexes]),
            'drinks': (data['Drinks'][indexes]),
            'gpa': data['Current GPA'][indexes]}

model_fit_1 = posterior_model_1.sample(data=data_fit, seed=2024)

df_3 = model_fit_1.draws_pd()
df_3.head()
# Out:
# 20:52:44 - cmdstanpy - INFO - compiling stan file /home/daniel/Documents/studies/data_analytics/project/src/posterior_model_1.stan to exe file /home/daniel/Documents/studies/data_analytics/project/src/posterior_model_1
# 20:52:59 - cmdstanpy - INFO - compiled model executable: /home/daniel/Documents/studies/data_analytics/project/src/posterior_model_1
# 20:52:59 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 20:52:59 - cmdstanpy - INFO - CmdStan done processing.
# 20:52:59 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is -23.2347, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -21.6048, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -1.88055, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -0.24571, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# Exception: normal_lpdf: Scale parameter is -4.47132, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -4.75799, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -1.76443, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# Exception: normal_lpdf: Scale parameter is -0.556705, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -0.459647, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -1.60679, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# 	Exception: normal_lpdf: Scale parameter is -26.8491, but must be positive! (in 'posterior_model_1.stan', line 34, column 8 to column 38)
# Consider re-running with show_console=True if the above output is unclear!
#    chain__  iter__  draw__     lp__  accept_stat__  stepsize__  treedepth__  \
# 0      1.0     1.0     1.0 -22.7839       0.822706    0.650375          3.0
# 1      1.0     2.0     2.0 -22.0661       0.998476    0.650375          3.0
# 2      1.0     3.0     3.0 -22.4494       0.907701    0.650375          2.0
# 3      1.0     4.0     4.0 -23.7501       0.862724    0.650375          3.0
# 4      1.0     5.0     5.0 -22.5891       1.000000    0.650375          3.0
#
#    n_leapfrog__  divergent__  energy__  ...  log_likelihood[1]  \
# 0           7.0          0.0   24.6639  ...           -3.95402
# 1           7.0          0.0   23.7129  ...           -2.98657
# 2           7.0          0.0   24.2197  ...           -3.33669
# 3           7.0          0.0   24.7942  ...           -2.79447
# 4           7.0          0.0   24.8234  ...           -3.43005
#
#    log_likelihood[2]  log_likelihood[3]  log_likelihood[4]  log_likelihood[5]  \
# 0           -3.02955           -4.04578           -2.83986           -3.32410
# 1           -3.68203           -3.00386           -2.63001           -2.73191
# 2           -3.26128           -3.31768           -2.78277           -2.99086
# 3           -4.30557           -2.86764           -2.41818           -2.50172
# 4           -3.20061           -3.45998           -2.80005           -3.07047
#
#    log_likelihood[6]  log_likelihood[7]  log_likelihood[8]  log_likelihood[9]  \
# 0           -2.63449           -2.83752           -2.50660           -3.54200
# 1           -3.19854           -3.38497           -2.68567           -2.81846
# 2           -2.95102           -3.17480           -2.65483           -3.06026
# 3           -3.44669           -3.57876           -2.62412           -2.64531
# 4           -2.89046           -3.09262           -2.65471           -3.17045
#
#    log_likelihood[10]
# 0            -2.57020
# 1            -3.30920
# 2            -2.94177
# 3            -3.67823
# 4            -2.83177
#
# [5 rows x 45 columns]

# %% [markdown]
# ### 5.2 Posterior predictive checks for parameters and measurements

# %%
columns = [f'predicted_gpa[{i+1}]' for i in range(10)]

fig, axes = plt.subplots(5, 2, figsize=(10, 25))

for i, column in enumerate(columns):    
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.histplot(data['Current GPA'], ax=ax, bins=len(data['Current GPA'].unique()), stat='density')
    sns.histplot(df_3[column], ax=ax, bins=len(data['Current GPA'].unique()), stat='density')
    
    ax.set_title(f'Prior distribution {column}')
    ax.set_xlabel('Predicted GPA [%]')
    if i == 0:
        ax.legend(['Observed GPA', 'Predicted GPA'])

plt.tight_layout()
plt.show()

# %%
sns.histplot(data['Current GPA'], bins=len(data['Current GPA'].unique()), stat='density')
sns.histplot(model_fit_1.stan_variable('predicted_gpa').flatten(), bins=len(data['Current GPA'].unique()), stat='density')

ax.set_title(f'Prior distribution {column}')
ax.set_xlabel('Predicted GPA [%]')
ax.legend(['Observed GPA', 'Predicted GPA'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Parameter marginal disrtibutions for first model

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 10))
sns.histplot(df_3['theta_1'], ax=axes[0][0], bins=30, stat='density')
sns.histplot(df_3['theta_2'], ax=axes[0][1], bins=30, stat='density')
sns.histplot(df_3['theta_3'], ax=axes[1][0], bins=30, stat='density')
sns.histplot(df_3['theta_4'], ax=axes[1][1], bins=30, stat='density')
sns.histplot(df_3['sigma'], ax=axes[2][0], bins=30, stat='density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Posterior analysis for the second model

# %% [markdown]
# ### 6.1 Issues with the sampling for second model
#
# For the second model, when sampling, the biggest problem was the appropriate transformation of the predictors passed as shape factors in the beta distribution. After a longer analysis, the relationship and the impact of adding appropriate predictors to the given shape coefficients were found and the final version of the model was obtained on this basis.

# %%
posterior_model_2 = CmdStanModel(stan_file='src/posterior_model_2.stan')

scaled_gpa = data['Current GPA'][indexes] / 100

data_fit = {'N': 10, 
            'hours': (data['Studying hours'][indexes]),
            'hangouts': (data['Hangouts'][indexes]),
            'drinks': data['Drinks'][indexes],
            'scaled_gpa': scaled_gpa}

model_fit_2 = posterior_model_2.sample(data=data_fit, seed=2024)

df_4 = model_fit_2.draws_pd()
df_4.head()
# Out:
# 21:21:26 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# 21:21:26 - cmdstanpy - INFO - CmdStan done processing.
# 21:21:26 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -0.19047, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.85404, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.79447, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.4952, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -1.35025, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[2] is -0.0815461, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.91725, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[6] is -0.460052, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.49237, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.95567, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.76184, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -6.28528, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[3] is -0.019606, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -2.51662, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.02116, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.59063, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.83254, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.61538, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[6] is -0.28441, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[3] is -0.242118, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -3.51201, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -15.3913, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -7.78318, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -4.08974, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -2160.05, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -43.9617, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -0.498973, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -0.140831, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -0.274242, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -6.34417, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[5] is -3.87511, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -0.580353, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -64.9707, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -3.76754, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -4.64888, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[4] is -0.32868, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -13.7041, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -13.492, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -2.80437, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -582.351, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: lognormal_lpdf: Random variable is -15.8558, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: lognormal_lpdf: Random variable is -1.12458, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -1.51927, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -3.75837, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -6.55304, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -7.47928, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[6] is -1.89045, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -2.05306, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -42.6285, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -3.39366, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.67439, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -1.9971, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -0.849749, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.85301, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -0.174795, but must be nonnegative! (in 'posterior_model_2.stan', line 31, column 4 to column 34)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.328507, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.86587, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -2.05456, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.31887, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.74288, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -3.0223, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -2.63374, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -3.08736, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -3.14246, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -0.0845855, but must be nonnegative! (in 'posterior_model_2.stan', line 29, column 4 to column 36)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -1.00655, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -1.08963, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[3] is -0.106394, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -0.349376, but must be nonnegative! (in 'posterior_model_2.stan', line 29, column 4 to column 36)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -4.47989, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -2.23975, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.709722, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.429479, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[3] is -0.194193, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.88911, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -2.17853, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.407285, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.31618, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -2.13212, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.289708, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -0.224392, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -4.74758, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -3.67656, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[3] is -0.267987, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -1.8994, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -1.09145, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -0.393456, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -4.80449, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -1.85086, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -4.36791, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -2115.79, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[7] is -52.5521, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -1.21633, but must be nonnegative! (in 'posterior_model_2.stan', line 33, column 4 to column 35)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[3] is -3.36446, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -0.149374, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# 	Exception: lognormal_lpdf: Random variable is -0.53694, but must be nonnegative! (in 'posterior_model_2.stan', line 32, column 4 to column 35)
# Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -4.32793, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[6] is -0.57811, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.491255, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -5.52136, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.452612, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: posterior_model_2_model_namespace::log_prob: alpha_param[1] is -0.297423, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 19, column 4 to column 39)
# 	Exception: lognormal_lpdf: Random variable is -1.73457, but must be nonnegative! (in 'posterior_model_2.stan', line 29, column 4 to column 36)
# 	Exception: lognormal_lpdf: Random variable is -4.26586, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: lognormal_lpdf: Random variable is -4.3399, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: lognormal_lpdf: Random variable is -1157.63, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: lognormal_lpdf: Random variable is -35.1552, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -35.2631, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[4] is -1.21902, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: posterior_model_2_model_namespace::log_prob: beta_param[1] is -3.10534, but must be greater than or equal to 0.000000 (in 'posterior_model_2.stan', line 20, column 4 to column 38)
# 	Exception: lognormal_lpdf: Random variable is -6.61717, but must be nonnegative! (in 'posterior_model_2.stan', line 30, column 4 to column 34)
# Consider re-running with show_console=True if the above output is unclear!
#    chain__  iter__  draw__      lp__  accept_stat__  stepsize__  treedepth__  \
# 0      1.0     1.0     1.0  0.832510       0.825716    0.661848          2.0
# 1      1.0     2.0     2.0  2.679390       0.997407    0.661848          3.0
# 2      1.0     3.0     3.0 -1.610130       0.728000    0.661848          2.0
# 3      1.0     4.0     4.0  0.573406       0.735646    0.661848          2.0
# 4      1.0     5.0     5.0  2.438900       0.993426    0.661848          2.0
#
#    n_leapfrog__  divergent__  energy__  ...  log_likelihood[1]  \
# 0           7.0          0.0  0.594335  ...            1.62280
# 1           7.0          0.0  0.276986  ...            1.30383
# 2           3.0          0.0  2.791250  ...            1.38485
# 3           3.0          0.0  7.145210  ...            1.42934
# 4           7.0          0.0 -0.003423  ...            1.50840
#
#    log_likelihood[2]  log_likelihood[3]  log_likelihood[4]  log_likelihood[5]  \
# 0           0.925197           1.257130            1.96385            1.70861
# 1           1.220170           0.941454            1.94112            1.42861
# 2           1.066850           1.196240            1.96437            1.60312
# 3           1.069240           1.155080            1.95989            1.57118
# 4           1.037280           1.203500            1.96425            1.65833
#
#    log_likelihood[6]  log_likelihood[7]  log_likelihood[8]  log_likelihood[9]  \
# 0            1.38091           1.249050            1.88130            1.42903
# 1            1.54809           1.308380            1.87035            1.19766
# 2            1.42630           0.949838            1.86912            1.52593
# 3            1.42500           1.071050            1.87660            1.42338
# 4            1.44966           1.235260            1.88116            1.43644
#
#    log_likelihood[10]
# 0             1.64460
# 1             1.77032
# 2             1.75191
# 3             1.72236
# 4             1.69939
#
# [5 rows x 55 columns]

# %% [markdown]
# ### 6.2 Posterior predictive checks for parameters and measurements

# %%
columns = [f'predicted_scaled_gpa[{i+1}]' for i in range(10)]

fig, axes = plt.subplots(5, 2, figsize=(10, 25))

for i, column in enumerate(columns):    
    row = i // 2
    col = i % 2
    ax = axes[row, col]
    
    sns.histplot(data['Current GPA'], ax=ax, bins=len(data['Current GPA'].unique()), stat='density')
    sns.histplot(df_4[column] * 100, ax=ax, bins=len(data['Current GPA'].unique()), stat='density')
    
    ax.set_title(f's: {data['Studying hours'][indexes[i]]}, h: {data['Hangouts'][indexes[i]]}, d: {data["Drinks"][indexes[i]]}')
    ax.set_xlabel('Predicted GPA [%]')
    if i == 0:
        ax.legend(['Observed GPA', 'Predicted GPA'])

plt.tight_layout()
plt.show()

# %%
sns.histplot(data['Current GPA'], bins=len(data['Current GPA'].unique()), stat='density')
sns.histplot(model_fit_2.stan_variable('predicted_scaled_gpa').flatten() * 100, bins=len(data['Current GPA'].unique()), stat='density')

ax.set_title(f'Prior distribution {column}')
ax.set_xlabel('Predicted GPA [%]')
ax.legend(['Observed GPA', 'Predicted GPA'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3 Parameter marginal disrtibutions for second model

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 10))
sns.histplot(df_4['theta_1'], ax=axes[0][0], bins=30, stat='density')
sns.histplot(df_4['theta_2'], ax=axes[0][1], bins=30, stat='density')
sns.histplot(df_4['theta_3'], ax=axes[1][0], bins=30, stat='density')
sns.histplot(df_4['theta_4'], ax=axes[1][1], bins=30, stat='density')
sns.histplot(df_4['theta_5'], ax=axes[2][0], bins=30, stat='density')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Model comparison

# %% [markdown]
# ### 7.1 Comparing using information criteria

# %%
fit1_az = az.from_cmdstanpy(posterior=model_fit_1,
                            log_likelihood='log_likelihood',
                            posterior_predictive='predicted_gpa',
                            observed_data={'kid_value': data["Current GPA"]})

fit2_az = az.from_cmdstanpy(posterior=model_fit_2,
                            log_likelihood='log_likelihood',
                            posterior_predictive='predicted_scaled_gpa',
                            observed_data={'kid_value': data["Current GPA"] / 100})

# %%
fit1_az
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
fit2_az
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
print(az.waic(fit1_az, pointwise=True))
print(az.waic(fit2_az, pointwise=True))
# Out:
# Computed from 4000 posterior samples and 10 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic   -31.13     0.93
# p_waic        0.91        -
# Computed from 4000 posterior samples and 10 observations log-likelihood matrix.
#
#           Estimate       SE
# elpd_waic    14.32     0.96
# p_waic        0.42        -

# %%
print(az.loo(fit1_az, pointwise=True))
print(az.loo(fit2_az, pointwise=True))
# Out:
# Computed from 4000 posterior samples and 10 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo   -31.14     0.93
# p_loo        0.92        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)       10  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%
#
# Computed from 4000 posterior samples and 10 observations log-likelihood matrix.
#
#          Estimate       SE
# elpd_loo    14.32     0.96
# p_loo        0.42        -
# ------
#
# Pareto k diagnostic values:
#                          Count   Pct.
# (-Inf, 0.5]   (good)       10  100.0%
#  (0.5, 0.7]   (ok)          0    0.0%
#    (0.7, 1]   (bad)         0    0.0%
#    (1, Inf)   (very bad)    0    0.0%

# %%
waic_comparison = az.compare({"model_normal_dist": fit1_az, "model_beta_dist": fit2_az}, ic="waic", scale="deviance")
loo_comparison = az.compare({"model_normal_dist": fit1_az, "model_beta_dist": fit2_az}, ic="loo", scale="deviance")

# %%
az.plot_compare(waic_comparison)
plt.title("WAIC comparison")
plt.show()
waic_comparison
# Out:
#                    rank  elpd_waic    p_waic  elpd_diff  weight        se  \
# model_beta_dist       0 -28.638040  0.418649   0.000000     1.0  1.914744
# model_normal_dist     1  62.259924  0.911123  90.897964     0.0  1.860259
#
#                         dse  warning     scale
# model_beta_dist    0.000000    False  deviance
# model_normal_dist  0.931343    False  deviance

# %% [markdown]
# ### 7.2 WAIC comparison results
#
# The model_beta_dist has a significantly lower WAIC score (-28) compared to the model_normal_dist (62), suggesting it fits the data better while being less complex.
#
# The difference in WAIC scores relative to the best model. For model_normal_dist, this is 91.44291, indicating it is significantly worse than model_beta_dist, which has a dWAIC of 0 by definition as it is the best model.
#
# Both models have False Warning status, meaning no issues were detected.

# %%
az.plot_compare(loo_comparison)
plt.title("LOO comparison")
plt.show()
loo_comparison
# Out:
#                    rank   elpd_loo     p_loo  elpd_diff  weight        se  \
# model_beta_dist       0 -28.634126  0.420606   0.000000     1.0  1.915554
# model_normal_dist     1  62.282451  0.922387  90.916577     0.0  1.864401
#
#                         dse  warning     scale
# model_beta_dist    0.000000    False  deviance
# model_normal_dist  0.932302    False  deviance

# %% [markdown]
# ### 7.3 LOO comparison results
#
# Same as with previous method, model_beta semms much better fitting than model_normal.
#
# Both models have False Warning status, meaning no issues were detected.

# %% [markdown]
# ### 8. Summary
#
# We analyzed a dataset and performed Bayesian modeling to predict GPA based on studying hours, hangouts, and drinks.
#
# The posterior predictive checks showed that the model with the beta distribution consistently outperformed the model with the normal distribution in predicting GPA. The parameter marginal distributions also indicated that the beta distribution model had more accurate coefficients for the predictors.
